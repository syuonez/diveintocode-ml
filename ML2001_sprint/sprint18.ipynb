# %%
# !pip install kaggle

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-6591005a-1416-458c-8408-db457e5191ab" name="files[]" multiple disabled />
#      <output id="result-6591005a-1416-458c-8408-db457e5191ab">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle (1).json to kaggle (1).json
# {'kaggle (1).json': b'{"username":"shinoda18","key":"6d383ada317b3aee272604b63d3d3f32"}'}

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive/

# %%
mkdir .kaggle

# %%
ls -a
# Out:
# ./  ../  .config/  drive/  .kaggle/  sample_data/

# %%
#cd drive/"My Drive"
# Out:
# /content/drive/My Drive

# %%
import json

token = {"username":"shinoda18","key":"6d383ada317b3aee272604b63d3d3f32"}
with open('/content/.kaggle/kaggle.json', 'w') as file:
    json.dump(token, file)

# %%
# !chmod 600 /content/.kaggle/kaggle.json

# %%
pwd
# Out:
# '/content/drive/My Drive'

# %%
ls -a .kaggle
# Out:
# ls: cannot access '.kaggle': No such file or directory

# %%
pwd
# Out:
# '/content/drive/My Drive'

# %%
cd '/content'
# Out:
# /content

# %%
pwd
# Out:
# '/content'

# %%
ls -a .kaggle
# Out:
# ./  ../  kaggle.json

# %%
mkdir　/root/.kaggle/

# %%
# !cp -R /content/.kaggle/kaggle.json /root/.kaggle/

# %%
# !ls -a /root/.kaggle/
# Out:
# .  ..  kaggle.json

# %%
# !kaggle competitions list
# Out:
# ...
# ref                                            deadline             category             reward  teamCount  userHasEntered
# ---------------------------------------------  -------------------  ---------------  ----------  ---------  --------------
# digit-recognizer                               2030-01-01 00:00:00  Getting Started   Knowledge       2198           False
# titanic                                        2030-01-01 00:00:00  Getting Started   Knowledge      16584           False
# house-prices-advanced-regression-techniques    2030-01-01 00:00:00  Getting Started   Knowledge       4521            True
# connectx                                       2030-01-01 00:00:00  Getting Started   Knowledge        329           False
# competitive-data-science-predict-future-sales  2020-12-31 23:59:00  Playground            Kudos       6027           False
# m5-forecasting-accuracy                        2020-06-30 23:59:00  Featured            $50,000       1213            True
# ...

# %%
# カレントディレクトリの変更

import os

os.chdir('/content/drive/My Drive/')

# カレントディレクトリの取得
print(os.getcwd())
# Out:
# /content/drive/My Drive

# %%
# !kaggle competitions download -c tgs-salt-identification-challenge
# Out:
# ...
#   0% 0.00/264k [00:00<?, ?B/s]
# 100% 264k/264k [00:00<00:00, 32.0MB/s]
# ...
#  96% 208M/217M [00:01<00:00, 133MB/s]
# 100% 217M/217M [00:01<00:00, 131MB/s]
# ...
#   0% 0.00/922k [00:00<?, ?B/s]
# 100% 922k/922k [00:00<00:00, 60.8MB/s]
# ...
#  82% 31.0M/37.9M [00:00<00:00, 135MB/s]
# 100% 37.9M/37.9M [00:00<00:00, 150MB/s]
# ...
#   0% 0.00/322k [00:00<?, ?B/s]
# 100% 322k/322k [00:00<00:00, 44.6MB/s]
# ...
#  94% 154M/163M [00:01<00:00, 139MB/s]
# 100% 163M/163M [00:01<00:00, 128MB/s]
# ...
#  92% 38.0M/41.4M [00:00<00:00, 76.5MB/s]
# 100% 41.4M/41.4M [00:00<00:00, 119MB/s]

# %%
# !unzip /content/drive/'My Drive'/competition_data.zip  -d TGS
# Out:
# ストリーミング出力は最後の 5000 行に切り捨てられました。
#   inflating: TGS/competition_data/train/masks/851a37ac37.png
#   inflating: TGS/__MACOSX/competition_data/train/masks/._851a37ac37.png
#   inflating: TGS/competition_data/train/masks/6010b9b84d.png
#   inflating: TGS/__MACOSX/competition_data/train/masks/._6010b9b84d.png
#   inflating: TGS/competition_data/train/masks/f64190c47e.png
#   inflating: TGS/__MACOSX/competition_data/train/masks/._f64190c47e.png
#   inflating: TGS/competition_data/train/masks/ec3130dd0b.png
#   inflating: TGS/__MACOSX/competition_data/train/masks/._ec3130dd0b.png
#   inflating: TGS/competition_data/train/masks/894b9ae774.png
#   inflating: TGS/__MACOSX/competition_data/train/masks/._894b9ae774.png
#   inflating: TGS/competition_data/train/masks/6a57dfd211.png
#   inflating: TGS/__MACOSX/competition_data/train/masks/._6a57dfd211.png
#   inflating: TGS/competition_data/train/masks/9b656c339a.png
#   inflating: TGS/__MACOSX/competition_data/train/masks/._9b656c339a.png
# ...

# %%
cd drive/"My Drive"
# Out:
# /content/drive/My Drive

# %%
# !unzip /content/drive/'My Drive'/train.zip -d train_sol
# Out:
# ストリーミング出力は最後の 5000 行に切り捨てられました。
#   inflating: train_sol/images/b012e9ebb0.png
#   inflating: train_sol/images/d3034e7a60.png
#   inflating: train_sol/images/ae2ef70d51.png
#   inflating: train_sol/images/1af44a9db0.png
#   inflating: train_sol/images/41cfd4b320.png
#   inflating: train_sol/images/853e89d0d3.png
#   inflating: train_sol/images/2a484baa26.png
#   inflating: train_sol/images/92e617896e.png
#   inflating: train_sol/images/b70f0ab0c2.png
#   inflating: train_sol/images/e8757626a1.png
#   inflating: train_sol/images/6a3d92ce59.png
#   inflating: train_sol/images/127ef4105f.png
#   inflating: train_sol/images/d21012f5c1.png
#   inflating: train_sol/images/1cb9549d2c.png
#   inflating: train_sol/images/e030bdae65.png
#   inflating: train_sol/images/0cf7155eb6.png
#   inflating: train_sol/images/badb3ea766.png
#   inflating: train_sol/images/9bd58061d6.png
#   inflating: train_sol/images/2b1e71c2a3.png
#   inflating: train_sol/images/28d42de29f.png
# ...

# %%
cd drive/"My Drive"
# Out:
# /content/drive/My Drive

# %%
# !unzip /content/drive/'My Drive'/test.zip -d test_sol
# Out:
# ストリーミング出力は最後の 5000 行に切り捨てられました。
#   inflating: test_sol/images/187ecc32d5.png
#   inflating: test_sol/images/54538419f5.png
#   inflating: test_sol/images/93614d4b95.png
#   inflating: test_sol/images/50a91adce8.png
#   inflating: test_sol/images/97d23cea10.png
#   inflating: test_sol/images/ca04c19c0b.png
#   inflating: test_sol/images/d168218bac.png
#   inflating: test_sol/images/a670e833a4.png
#   inflating: test_sol/images/a964a0f499.png
#   inflating: test_sol/images/371bf59030.png
#   inflating: test_sol/images/fc74f77bae.png
#   inflating: test_sol/images/f63dc1e3be.png
#   inflating: test_sol/images/b807539a5f.png
#   inflating: test_sol/images/1dfcbf4bca.png
#   inflating: test_sol/images/a971d2ae53.png
#   inflating: test_sol/images/4ad823e2d3.png
#   inflating: test_sol/images/85a9687a4f.png
#   inflating: test_sol/images/da5b430ecd.png
#   inflating: test_sol/images/b1a2903d1c.png
#   inflating: test_sol/images/70958cacd4.png
#   inflating: test_sol/images/2093e5c98e.png
# ...

# %%
pwd
# Out:
# '/content/drive/My Drive'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !git clone https://github.com/zhixuhao/unet
# Out:
# Cloning into 'unet'...
# remote: Enumerating objects: 394, done.
# remote: Total 394 (delta 0), reused 0 (delta 0), pack-reused 394
# Receiving objects: 100% (394/394), 44.92 MiB | 27.21 MiB/s, done.
# Resolving deltas: 100% (79/79), done.
# Checking out files: 100% (253/253), done.

# %%
pwd
# Out:
# '/content'

# %%
import os

# %%
print(os)
# Out:
# <module 'os' from '/usr/lib/python3.6/os.py'>

# %%
# カレントディレクトリの変更

import os

os.chdir('/content/drive/My Drive/unet/data/membrane/test')

# カレントディレクトリの取得
print(os.getcwd())
# Out:
# /content/drive/My Drive/unet/data/membrane/test

# %%
pwd
# Out:
# '/content/drive/My Drive/unet/data/membrane/test'

# %%
# ファイル名は連番でないと読めないプログラムになっているので、リネイムする。
# 初めに今のファイル名の状態やレコード数を確認する。
path = '/content/drive/My Drive/unet/data/membrane/test' 
flist = os.listdir(path)
flist[:50]
#rename の実施をする。
for i , name in enumerate(flist):
    renamed = str(i)+".png"
    os.rename(name, renamed)

#path = '/content/drive/My Drive/test_sol/images'
#flist_renamed = os.listdir(path)
#sorted(flist_renamed)[50:]

# %%
flist
# Out:
# ['0.jpg',
#  '10000.jpg',
#  '10001.jpg',
#  '10002.jpg',
#  '10003.jpg',
#  '10004.jpg',
#  '10005.jpg',
#  '10006.jpg',
#  '10007.jpg',
#  '10008.jpg',
#  '10009.jpg',
#  '1000.jpg',
#  '10010.jpg',
#  '10011.jpg',
#  '10012.jpg',
#  '10013.jpg',
#  '10014.jpg',
#  '10015.jpg',
#  '10016.jpg',
#  '10017.jpg',
#  '10018.jpg',
#  '10019.jpg',
#  '1001.jpg',
#  '10020.jpg',
#  '10021.jpg',
#  '10022.jpg',
#  '10023.jpg',
#  '10024.jpg',
#  '10025.jpg',
#  '10026.jpg',
#  '10027.jpg',
#  '10028.jpg',
#  '10029.jpg',
#  '1002.jpg',
#  '10030.jpg',
#  '10031.jpg',
#  '10032.jpg',
#  '10033.jpg',
#  '10034.jpg',
#  '10035.jpg',
#  '10036.jpg',
#  '10037.jpg',
#  '10038.jpg',
#  '10039.jpg',
#  '1003.jpg',
#  '10040.jpg',
#  '10041.jpg',
#  '10042.jpg',
#  '10043.jpg',
#  '10044.jpg',
#  '10045.jpg',
#  '10046.jpg',
#  '10047.jpg',
#  '10048.jpg',
#  '10049.jpg',
#  '1004.jpg',
#  '10050.jpg',
#  '10051.jpg',
#  '10052.jpg',
#  '10053.jpg',
#  '10054.jpg',
#  '10055.jpg',
#  '10056.jpg',
# ...

# %%
rm /content/drive/'My Drive'/unet/data/membrane/train/image/*

# %%
# !cp /content/drive/'My Drive'/train_sol/images/* /content/drive/'My Drive'/unet/data/membrane/train/image

# %%
rm /content/drive/'My Drive'/unet/data/membrane/test/*

# %%
# !cp /content/drive/'My Drive'/test_sol/images/* /content/drive/'My Drive'/unet/data/membrane/test
# Out:
# cp: -r not specified; omitting directory '/content/drive/My Drive/test_sol/images/unet'

# %%
rm /content/drive/'My Drive'/unet/data/membrane/train/label/*

# %%
# !cp /content/drive/'My Drive'/train_sol/masks/* /content/drive/'My Drive'/unet/data/membrane/train/label

# %%
import os

os.chdir("/content/drive/My Drive/unet")
print(os.getcwd())
# Out:
# /content/drive/My Drive/unet

# %%
pwd
# Out:
# '/content/drive/My Drive/unet'

# %%
# !mkdir result_data

# %%
from model import *
from data import *

#os.environ["CUDA_VISIBLE_DEVICES"] = "0"


data_gen_args = dict(rotation_range=0.2,
                    width_shift_range=0.05,
                    height_shift_range=0.05,
                    shear_range=0.05,
                    zoom_range=0.05,
                    horizontal_flip=True,
                    fill_mode='nearest')
myGene = trainGenerator(2,'/content/drive/My Drive/unet/data/membrane/train','image','label',data_gen_args,save_to_dir = None)
#data/membrane/train
model = unet()
model_checkpoint = ModelCheckpoint('unet_membrane.hdf5', monitor='loss',verbose=1, save_best_only=True)
model.fit_generator(myGene,steps_per_epoch=300,epochs=1,callbacks=[model_checkpoint])

testGene = testGenerator("/content/drive/My Drive/unet/data/membrane/test")
results = model.predict_generator(testGene,30,verbose=1)
saveResult("/content/drive/My Drive/unet/result_data",results)
# Out:
# /content/drive/My Drive/unet/model.py:55: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("co...)`
#   model = Model(input = inputs, output = conv10)
# Epoch 1/1
# Found 4000 images belonging to 1 classes.
# Found 4000 images belonging to 1 classes.
# 300/300 [==============================] - 76s 252ms/step - loss: 0.6119 - acc: 0.7420
#
# Epoch 00001: loss improved from inf to 0.61192, saving model to unet_membrane.hdf5
# 30/30 [==============================] - 3s 94ms/step
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# ...

# %%
/content/drive/My Drive/unet/data/membrane/test

# %%
from PIL import Image
from IPython.display import display
pred = '/content/drive/My Drive/unet/result_data/0_predict.png'
display(Image.open(pred))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=L size=256x256 at 0x7F7244A7C4A8>

# %% [markdown]
# 【問題2】コードリーディング

# %% [markdown]
# 論文[1]に目を通した上で、上記実装のコードリーディングを行ってください。

# %% [markdown]
# # data.py
# adjustData
# *   画像データを数値データに変換する関数
#
# trainGenerator
# * train用画像データを拡張し、テンソル形式に変換する関数
#
# testGenerator
# * test画像を読み込んで、テンソル形式に変換する関数
#
# labelVisualize
# * ３次元に変換した上で正規化を行っている関数
#
# saveResult
# * 推定結果を保存する関数

# %% [markdown]
# # main.py¶
# * trainGeneratorのインスタンス化
# * unetのインスタンス化
# * ModelCheckpointをインスタンス化（unet_membrane.hdf5に最良のモデルをエポックごとに保存）
# * keras.modelからfit_generatorを呼び出しtrainGeneratorを学習
# *  testGeneratorをインスタンス化
# * keras.modelからpredict_generatorを呼び出し、予測する
# saveResultにより予測値を保存
